# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.graphics.regressionplots import influence_plot

# %%
# Getting error while opening csv file,so opening in exel format
data=pd.read_excel("C:/Users/rupesh/Downloads/ToyotaCorolla.xlsx")
data
# Out:
#         Id                                              Model  Price  \
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1431  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1432  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1433  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1434  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1435  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  ...  \
# ...

# %%
data=data[["Price","Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax","Weight"]]
data
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500         69  20544   86  1300      3      5             69    1025
# 1432  10845         72  19000   86  1300      3      5             69    1015
# 1433   8500         71  17016   86  1300      3      5             69    1015
# 1434   7250         70  16916   86  1300      3      5             69    1015
# 1435   6950         76      1  110  1600      5      5             19    1114
#
# [1436 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Price          1436 non-null   int64
#  1   Age_08_04      1436 non-null   int64
#  2   KM             1436 non-null   int64
#  3   HP             1436 non-null   int64
#  4   cc             1436 non-null   int64
#  5   Doors          1436 non-null   int64
#  6   Gears          1436 non-null   int64
#  7   Quarterly_Tax  1436 non-null   int64
#  8   Weight         1436 non-null   int64
# dtypes: int64(9)
# memory usage: 101.1 KB

# %% [markdown]
# ## EDA

# %%
data.describe()
# Out:
#               Price    Age_08_04             KM           HP           cc  \
# count   1436.000000  1436.000000    1436.000000  1436.000000   1436.00000
# mean   10730.824513    55.947075   68533.259749   101.502089   1576.85585
# std     3626.964585    18.599988   37506.448872    14.981080    424.38677
# min     4350.000000     1.000000       1.000000    69.000000   1300.00000
# 25%     8450.000000    44.000000   43000.000000    90.000000   1400.00000
# 50%     9900.000000    61.000000   63389.500000   110.000000   1600.00000
# 75%    11950.000000    70.000000   87020.750000   110.000000   1600.00000
# max    32500.000000    80.000000  243000.000000   192.000000  16000.00000
#
#              Doors        Gears  Quarterly_Tax      Weight
# count  1436.000000  1436.000000    1436.000000  1436.00000
# mean      4.033426     5.026462      87.122563  1072.45961
# std       0.952677     0.188510      41.128611    52.64112
# min       2.000000     3.000000      19.000000  1000.00000
# ...

# %%
data[data.isnull()].sum()
# Out:
# Price            0.0
# Age_08_04        0.0
# KM               0.0
# HP               0.0
# cc               0.0
# Doors            0.0
# Gears            0.0
# Quarterly_Tax    0.0
# Weight           0.0
# dtype: float64

# %%
data[data.duplicated()]
# Out:
#      Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 113  24950          8  13253  116  2000      5      5            234    1320

# %%
data=data.drop_duplicates().reset_index(drop=True)
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Price, Age_08_04, KM, HP, cc, Doors, Gears, Quarterly_Tax, Weight]
# Index: []

# %%
data.corr()
# Out:
#                   Price  Age_08_04        KM        HP        cc     Doors  \
# Price          1.000000  -0.876273 -0.569420  0.314134  0.124375  0.183604
# Age_08_04     -0.876273   1.000000  0.504575 -0.155293 -0.096549 -0.146929
# KM            -0.569420   0.504575  1.000000 -0.332904  0.103822 -0.035193
# HP             0.314134  -0.155293 -0.332904  1.000000  0.035207  0.091803
# cc             0.124375  -0.096549  0.103822  0.035207  1.000000  0.079254
# Doors          0.183604  -0.146929 -0.035193  0.091803  0.079254  1.000000
# Gears          0.063831  -0.005629  0.014890  0.209642  0.014732 -0.160101
# Quarterly_Tax  0.211508  -0.193319  0.283312 -0.302287  0.305982  0.107353
# Weight         0.575869  -0.466484 -0.023969  0.087143  0.335077  0.301734
#
#                   Gears  Quarterly_Tax    Weight
# Price          0.063831       0.211508  0.575869
# Age_08_04     -0.005629      -0.193319 -0.466484
# KM             0.014890       0.283312 -0.023969
# ...

# %%
sns.heatmap(data=data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.set_style(style="darkgrid")
sns.pairplot(data=data)

# %%
plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
data["Price"].hist()
plt.subplot(2,2,2)
data["Age_08_04"].hist()
plt.subplot(2,2,3)
data["KM"].hist()
plt.subplot(2,2,4)
data["Weight"].hist()
# Out:
# <AxesSubplot:>

# %%
data=data.rename({'Age_08_04':'Age','cc':'CC','Quarterly_Tax':'QT'},axis=1)
data.head()
# Out:
#    Price  Age     KM  HP    CC  Doors  Gears   QT  Weight
# 0  13500   23  46986  90  2000      3      5  210    1165
# 1  13750   23  72937  90  2000      3      5  210    1165
# 2  13950   24  41711  90  2000      3      5  210    1165
# 3  14950   26  48000  90  2000      3      5  210    1165
# 4  13750   30  38500  90  2000      3      5  210    1170

# %% [markdown]
# ## Building Model

# %%
model=smf.ols("Price~+Age+KM+HP+CC+Doors+Gears+QT+Weight",data=data).fit()

# %%
model.params
# Out:
# Intercept   -5472.540368
# Age          -121.713891
# KM             -0.020737
# HP             31.584612
# CC             -0.118558
# Doors          -0.920189
# Gears         597.715894
# QT              3.858805
# Weight         16.855470
# dtype: float64

# %%
model.tvalues,model.pvalues
# Out:
# (Intercept    -3.875273
#  Age         -46.551876
#  KM          -16.552424
#  HP           11.209719
#  CC           -1.316436
#  Doors        -0.023012
#  Gears         3.034563
#  QT            2.944198
#  Weight       15.760663
#  dtype: float64,
#  Intercept     1.113392e-04
#  Age          1.879217e-288
#  KM            1.994713e-56
#  HP            5.211155e-28
#  CC            1.882393e-01
#  Doors         9.816443e-01
#  Gears         2.452430e-03
#  QT            3.290363e-03
#  Weight        1.031118e-51
#  dtype: float64)

# %%
model.rsquared,model.rsquared_adj
# Out:
# (0.8625200256947, 0.8617487495415146)

# %% [markdown]
# ## Building SLR Models

# %%
model_cc=smf.ols("Price~CC",data=data).fit()

# %%
model_cc.tvalues,model_cc.pvalues
# Out:
# (Intercept    24.879592
#  CC            4.745039
#  dtype: float64,
#  Intercept    7.236022e-114
#  CC            2.292856e-06
#  dtype: float64)

# %%
model_door=smf.ols("Price~Doors",data=data).fit()

# %%
model_door.tvalues,model_door.pvalues
# Out:
# (Intercept    19.421546
#  Doors         7.070520
#  dtype: float64,
#  Intercept    8.976407e-75
#  Doors        2.404166e-12
#  dtype: float64)

# %%
model_ccd=smf.ols("Price~CC+Doors",data=data).fit()

# %%
model_ccd.tvalues,model_ccd.pvalues
# Out:
# (Intercept    12.786341
#  CC            4.268006
#  Doors         6.752236
#  dtype: float64,
#  Intercept    1.580945e-35
#  CC           2.101878e-05
#  Doors        2.109558e-11
#  dtype: float64)

# %% [markdown]
# ## Calculating VIF

# %%
rsq_age=smf.ols("Age~KM+HP+CC+Doors+Gears+QT+Weight",data=data).fit().rsquared
vif_age=1/(1-rsq_age)
rsq_km=smf.ols("KM~Age+HP+CC+Doors+Gears+QT+Weight",data=data).fit().rsquared
vif_km=1/(1-rsq_km)
rsq_HP=smf.ols("HP~KM+Age+CC+Doors+Gears+QT+Weight",data=data).fit().rsquared
vif_HP=1/(1-rsq_HP)
rsq_CC=smf.ols("CC~HP+KM+Age+Doors+Gears+QT+Weight",data=data).fit().rsquared
vif_CC=1/(1-rsq_CC)
rsq_door=smf.ols("Doors~HP+KM+Age+CC+Gears+QT+Weight",data=data).fit().rsquared
vif_door=1/(1-rsq_door)
rsq_g=smf.ols("Gears~HP+KM+Age+CC+Doors+QT+Weight",data=data).fit().rsquared
vif_g=1/(1-rsq_g)
rsq_qt=smf.ols("QT~HP+KM+Age+CC+Doors+Gears+Weight",data=data).fit().rsquared
vif_qt=1/(1-rsq_qt)
rsq_w=smf.ols("Weight~HP+KM+Age+CC+Doors+Gears+QT",data=data).fit().rsquared
vif_w=1/(1-rsq_w)

print("age:",vif_age,"\n"
     "KH:",vif_km,"\n"
     "HP:",vif_HP,"\n"
     "CC:",vif_CC,"\n"
     "Doors:",vif_door,"\n"
     "Gears:",vif_g,"\n"
     "QT:",vif_g,"\n"
     "Weight",vif_w)
# Out:
# age: 1.8762358497682892
# KH: 1.75717802398104
# HP: 1.4191801087182137
# CC: 1.163470364594085
# Doors: 1.1558898658142074
# Gears: 1.0988429081631146
# QT: 1.0988429081631146
# Weight 2.4871800071791843

# %%
# All VIF are less than 20, so taking all variables in model

# %% [markdown]
# ## Residual Plot

# %%
import statsmodels.api as sm
qqplot=sm.qqplot(model.resid,line='q') # line = 45 to draw the diagnoal line
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %% [markdown]
# ## Residual Plot for Homoscedasticity

# %%
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std()

# %%
plt.scatter(get_standardized_values(model.fittedvalues),
            get_standardized_values(model.resid))

plt.title('Residual Plot')
plt.xlabel('Standardized Fitted values')
plt.ylabel('Standardized residual values')
plt.show()

# %% [markdown]
# ## Residual Vs Regressors

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'Age',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'HP',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'CC',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'QT',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'Doors',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'Weight',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'KM',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'Gears',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %% [markdown]
# # Model Deletion Diagnostics
#
# ## Cook’s Distance

# %%
(c,_)=model.get_influence().cooks_distance
c
# Out:
# array([7.22221054e-03, 3.94547973e-03, 5.44224039e-03, ...,
#        8.04110550e-07, 6.99854767e-04, 1.08408002e-02])

# %%
fig=plt.figure(figsize=(20,7))
plt.stem(np.arange(len(data)),np.round(c,5))
plt.xlabel('Row Index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
(np.argmax(c),np.max(c))
# Out:
# (80, 78.7295058224851)

# %%
influence_plot(model)
plt.show()

# %%
k=data.shape[1]
n=data.shape[0]
leverage_cutoff = (3*(k+1))/n
leverage_cutoff
# Out:
# 0.020905923344947737

# %%
data[data.index.isin([80])]
# Out:
#     Price  Age     KM   HP     CC  Doors  Gears   QT  Weight
# 80  18950   25  20019  110  16000      5      5  100    1180

# %%
data1=data.drop(data.index[[80]],axis=0).reset_index(drop=True)
data1.head()
# Out:
#    Price  Age     KM  HP    CC  Doors  Gears   QT  Weight
# 0  13500   23  46986  90  2000      3      5  210    1165
# 1  13750   23  72937  90  2000      3      5  210    1165
# 2  13950   24  41711  90  2000      3      5  210    1165
# 3  14950   26  48000  90  2000      3      5  210    1165
# 4  13750   30  38500  90  2000      3      5  210    1170

# %% [markdown]
# # Improving the model

# %%
New_model=smf.ols("Price~+Age+KM+HP+CC+Doors+Gears+QT+Weight",data=data1).fit()
New_model.rsquared , New_model.aic
print("Thus model accuracy is improved to",New_model.rsquared)
# Out:
# Thus model accuracy is improved to 0.8681163912634053

# %% [markdown]
# # Prediction

# %%
pred_y=New_model.predict(data1)
pred_y.head()
# Out:
# 0    16513.565909
# 1    16051.656226
# 2    16486.949796
# 3    16133.995128
# 4    15921.372341
# dtype: float64

# %%
d1={'Models':['Model','New_Model'],'Rsquared':[model.rsquared,New_model.rsquared]}
R_squ=pd.DataFrame(d1)
R_squ
# Out:
#       Models  Rsquared
# 0      Model  0.862520
# 1  New_Model  0.868116
